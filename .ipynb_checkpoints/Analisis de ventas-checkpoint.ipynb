# %%
#se realizara un analisis de ventas, son archivos csv que se encuentran separado un archivo por mes

# %%
import pandas as pd
import os 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Tarea 1: combinar los 12 meses de datos de ventas en un solo csv y luego leer el nuevo archivo

# %%
path= "C:/Users/milag/proyectos-python/Analisis-Ventas/Ventas-data"
files= os.listdir(path)
DF= pd.DataFrame()
for file in files :
    df= pd.read_csv(path+"/"+file)
    DF=pd.concat([df,DF])
DF.to_csv(r'C:\Users\milag\proyectos-python\Analisis-Ventas\ventas_12meses.csv',index=False)

# %%
#leer el nuevo archivo
data_completa= pd.read_csv(r'C:\Users\milag\proyectos-python\Analisis-Ventas\ventas_12meses.csv')

# %%
data_completa.head()
# Out:
#   Order ID                Product Quantity Ordered Price Each      Order Date  \
# 0   248151  AA Batteries (4-pack)                4       3.84  09/17/19 14:44
# 1   248152   USB-C Charging Cable                2      11.95  09/29/19 10:19
# 2   248153   USB-C Charging Cable                1      11.95  09/16/19 17:48
# 3   248154       27in FHD Monitor                1     149.99  09/27/19 07:52
# 4   248155   USB-C Charging Cable                1      11.95  09/01/19 19:03
#
#                         Purchase Address
# 0    380 North St, Los Angeles, CA 90001
# 1           511 8th St, Austin, TX 73301
# 2  151 Johnson St, Los Angeles, CA 90001
# 3      355 Hickory St, Seattle, WA 98101
# 4          125 5th St, Atlanta, GA 30301

# %% [markdown]
# ### Tarea2: limpieza y transformación de la data

# %%
#verificar cuanta data de las columnas del df estan vacias
data_completa.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
#eliminar las filas vacias 
#0 filas
data_completa.dropna(axis=0, how='any',inplace=True)

# %%
#verificar cuanta data de las columnas del df estan vacias
data_completa.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
#cambiar el tipo de dato
#primero verificar el continido 
data_completa['Quantity Ordered'].value_counts()
# Out:
# 1                   168552
# 2                    13324
# 3                     2920
# 4                      806
# Quantity Ordered       355
# 5                      236
# 6                       80
# 7                       24
# 8                        5
# 9                        3
# Name: Quantity Ordered, dtype: int64

# %%
#eliminar las filas que tienen por dato los nombres de la columna
# se obtienes los indices data_completa[data_completa['Quantity Ordered']== 'Quantity Ordered'].index
data_completa.drop(data_completa[data_completa['Quantity Ordered']== 'Quantity Ordered'].index,axis=0, inplace=True)

# %%
#NOTA: se tiene la data del 0 al 2  data_completa.iloc[:3]

# %%
#verificando que la data se haya eliminado
data_completa[data_completa['Quantity Ordered']== 'Quantity Ordered']
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %%
#verificar que tipo de datos tienen las columnas
data_completa.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
#cambio de tipo
data_completa['Quantity Ordered']= data_completa['Quantity Ordered'].astype(int)
data_completa['Price Each']= data_completa['Price Each'].astype(float)
data_completa['Order Date']= pd.to_datetime(data_completa['Order Date'])

# %%
#verificar el cambio de tipo de datos
data_completa.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int32
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# dtype: object

# %% [markdown]
# ### Tarea 3: Analisis

# %% [markdown]
# ### ¿Cuál fue el mejor mes en venta?¿ Cuanto se gano ese mes?

# %%
#crear una nueva columna del mes
data_completa['Month Order']=data_completa['Order Date'].dt.month

# %%
#crear una nueva columna de las ventas
data_completa['Sales']= data_completa['Quantity Ordered']*data_completa['Price Each']

# %%
data_completa
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        248151     AA Batteries (4-pack)                 4        3.84
# 1        248152      USB-C Charging Cable                 2       11.95
# 2        248153      USB-C Charging Cable                 1       11.95
# 3        248154          27in FHD Monitor                 1      149.99
# 4        248155      USB-C Charging Cable                 1       11.95
# ...         ...                       ...               ...         ...
# 186845   194090              Google Phone                 1      600.00
# 186846   194091     AA Batteries (4-pack)                 1        3.84
# 186847   194092    AAA Batteries (4-pack)                 2        2.99
# 186848   194093     AA Batteries (4-pack)                 1        3.84
# 186849   194094  Lightning Charging Cable                 1       14.95
#
#                 Order Date                        Purchase Address  \
# 0      2019-09-17 14:44:00     380 North St, Los Angeles, CA 90001
# 1      2019-09-29 10:19:00            511 8th St, Austin, TX 73301
# 2      2019-09-16 17:48:00   151 Johnson St, Los Angeles, CA 90001
# 3      2019-09-27 07:52:00       355 Hickory St, Seattle, WA 98101
# 4      2019-09-01 19:03:00           125 5th St, Atlanta, GA 30301
# ...                    ...                                     ...
# 186845 2019-04-08 17:11:00   177 Jackson St, Los Angeles, CA 90001
# 186846 2019-04-15 16:02:00         311 Forest St, Austin, TX 73301
# 186847 2019-04-28 14:36:00  347 Sunset St, San Francisco, CA 94016
# 186848 2019-04-14 15:09:00         835 Lake St, Portland, OR 97035
# 186849 2019-04-18 11:08:00          354 North St, Boston, MA 02215
#
#         Month Order   Sales
# 0                 9   15.36
# 1                 9   23.90
# 2                 9   11.95
# 3                 9  149.99
# 4                 9   11.95
# ...             ...     ...
# 186845            4  600.00
# 186846            4    3.84
# 186847            4    5.98
# 186848            4    3.84
# 186849            4   14.95
#
# [185950 rows x 8 columns]

# %%
data_completa.groupby(by='Month Order').sum().sort_values(by='Sales',ascending=False)
# Out:
#              Quantity Ordered    Price Each         Sales
# Month Order
# 12                      28114  4.588415e+06  4.613443e+06
# 10                      22703  3.715555e+06  3.736727e+06
# 4                       20558  3.367671e+06  3.390670e+06
# 11                      19798  3.180601e+06  3.199603e+06
# 5                       18667  3.135125e+06  3.152607e+06
# 3                       17005  2.791208e+06  2.807100e+06
# 7                       16072  2.632540e+06  2.647776e+06
# 6                       15253  2.562026e+06  2.577802e+06
# 8                       13448  2.230345e+06  2.244468e+06
# 2                       13449  2.188885e+06  2.202022e+06
# 9                       13109  2.084992e+06  2.097560e+06
# 1                       10903  1.811768e+06  1.822257e+06

# %%
meses= range(1,13)
ventas= data_completa.groupby(by='Month Order').sum()['Sales']

# %%
#verlo en grafica
plt.bar(meses,ventas)
plt.xlabel("MESES")
plt.ylabel("VENTAS")
plt.show()

# %% [markdown]
# #### el mes en donde mas se vendio fue diciembre

# %% [markdown]
# ### ¿Que ciudad tuvo mayor ventas?

# %%
#agregar columna ciudad
def obtener_ciudad(city):
    return city.str.split(",", expand=True)[1]
    
def obtener_estado(estado):
    return estado.str.split(",", expand=True)[2]
data_completa['City']=obtener_ciudad(data_completa['Purchase Address'])+' '+obtener_estado(data_completa['Purchase Address'])

# %%
data_completa
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        248151     AA Batteries (4-pack)                 4        3.84
# 1        248152      USB-C Charging Cable                 2       11.95
# 2        248153      USB-C Charging Cable                 1       11.95
# 3        248154          27in FHD Monitor                 1      149.99
# 4        248155      USB-C Charging Cable                 1       11.95
# ...         ...                       ...               ...         ...
# 186845   194090              Google Phone                 1      600.00
# 186846   194091     AA Batteries (4-pack)                 1        3.84
# 186847   194092    AAA Batteries (4-pack)                 2        2.99
# 186848   194093     AA Batteries (4-pack)                 1        3.84
# 186849   194094  Lightning Charging Cable                 1       14.95
#
#                 Order Date                        Purchase Address  \
# 0      2019-09-17 14:44:00     380 North St, Los Angeles, CA 90001
# 1      2019-09-29 10:19:00            511 8th St, Austin, TX 73301
# 2      2019-09-16 17:48:00   151 Johnson St, Los Angeles, CA 90001
# 3      2019-09-27 07:52:00       355 Hickory St, Seattle, WA 98101
# 4      2019-09-01 19:03:00           125 5th St, Atlanta, GA 30301
# ...                    ...                                     ...
# 186845 2019-04-08 17:11:00   177 Jackson St, Los Angeles, CA 90001
# 186846 2019-04-15 16:02:00         311 Forest St, Austin, TX 73301
# 186847 2019-04-28 14:36:00  347 Sunset St, San Francisco, CA 94016
# 186848 2019-04-14 15:09:00         835 Lake St, Portland, OR 97035
# 186849 2019-04-18 11:08:00          354 North St, Boston, MA 02215
#
#         Month Order   Sales                      City
# 0                 9   15.36     Los Angeles  CA 90001
# 1                 9   23.90          Austin  TX 73301
# 2                 9   11.95     Los Angeles  CA 90001
# 3                 9  149.99         Seattle  WA 98101
# 4                 9   11.95         Atlanta  GA 30301
# ...             ...     ...                       ...
# 186845            4  600.00     Los Angeles  CA 90001
# 186846            4    3.84          Austin  TX 73301
# 186847            4    5.98   San Francisco  CA 94016
# 186848            4    3.84        Portland  OR 97035
# 186849            4   14.95          Boston  MA 02215
#
# [185950 rows x 9 columns]

# %%
data_completa.groupby(by='City').sum().sort_values(by='Sales',ascending=False)
# Out:
#                           Quantity Ordered    Price Each  Month Order  \
# City
#  San Francisco  CA 94016             50239  8.211462e+06       315520
#  Los Angeles  CA 90001               33289  5.421435e+06       208325
#  New York City  NY 10001             27932  4.635371e+06       175741
#  Boston  MA 02215                    22528  3.637410e+06       141112
#  Atlanta  GA 30301                   16602  2.779908e+06       104794
#  Dallas  TX 75001                    16730  2.752628e+06       104620
#  Seattle  WA 98101                   16553  2.733296e+06       104941
#  Portland  OR 97035                  11303  1.860558e+06        70621
#  Austin  TX 73301                    11153  1.809874e+06        69829
#  Portland  ME 04101                   2750  4.471893e+05        17144
#
#                                  Sales
# City
#  San Francisco  CA 94016  8.262204e+06
#  Los Angeles  CA 90001    5.452571e+06
#  New York City  NY 10001  4.664317e+06
#  Boston  MA 02215         3.661642e+06
#  Atlanta  GA 30301        2.795499e+06
#  Dallas  TX 75001         2.767975e+06
#  Seattle  WA 98101        2.747755e+06
#  Portland  OR 97035       1.870732e+06
#  Austin  TX 73301         1.819582e+06
#  Portland  ME 04101       4.497583e+05

# %%
ventas_ciudad=data_completa.groupby('City').sum()['Sales']
ciudades=[ciudad for ciudad, df in data_completa.groupby('City')]

# %%
#verlo en grafica
plt.bar(ciudades,ventas_ciudad)
plt.xticks(ciudades,rotation='vertical', size=8)
plt.xlabel("ciudades")
plt.ylabel("ventas")
plt.show()

# %% [markdown]
# #### la ciudad de mas ventas es San Francisco CA 94016

# %% [markdown]
# ### ¿A qué hora debemos mostrar anuncios para maximizar la probabilidad de que el cliente compre el producto?

# %%
data_completa
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        248151     AA Batteries (4-pack)                 4        3.84
# 1        248152      USB-C Charging Cable                 2       11.95
# 2        248153      USB-C Charging Cable                 1       11.95
# 3        248154          27in FHD Monitor                 1      149.99
# 4        248155      USB-C Charging Cable                 1       11.95
# ...         ...                       ...               ...         ...
# 186845   194090              Google Phone                 1      600.00
# 186846   194091     AA Batteries (4-pack)                 1        3.84
# 186847   194092    AAA Batteries (4-pack)                 2        2.99
# 186848   194093     AA Batteries (4-pack)                 1        3.84
# 186849   194094  Lightning Charging Cable                 1       14.95
#
#                 Order Date                        Purchase Address  \
# 0      2019-09-17 14:44:00     380 North St, Los Angeles, CA 90001
# 1      2019-09-29 10:19:00            511 8th St, Austin, TX 73301
# 2      2019-09-16 17:48:00   151 Johnson St, Los Angeles, CA 90001
# 3      2019-09-27 07:52:00       355 Hickory St, Seattle, WA 98101
# 4      2019-09-01 19:03:00           125 5th St, Atlanta, GA 30301
# ...                    ...                                     ...
# 186845 2019-04-08 17:11:00   177 Jackson St, Los Angeles, CA 90001
# 186846 2019-04-15 16:02:00         311 Forest St, Austin, TX 73301
# 186847 2019-04-28 14:36:00  347 Sunset St, San Francisco, CA 94016
# 186848 2019-04-14 15:09:00         835 Lake St, Portland, OR 97035
# 186849 2019-04-18 11:08:00          354 North St, Boston, MA 02215
#
#         Month Order   Sales                      City
# 0                 9   15.36     Los Angeles  CA 90001
# 1                 9   23.90          Austin  TX 73301
# 2                 9   11.95     Los Angeles  CA 90001
# 3                 9  149.99         Seattle  WA 98101
# 4                 9   11.95         Atlanta  GA 30301
# ...             ...     ...                       ...
# 186845            4  600.00     Los Angeles  CA 90001
# 186846            4    3.84          Austin  TX 73301
# 186847            4    5.98   San Francisco  CA 94016
# 186848            4    3.84        Portland  OR 97035
# 186849            4   14.95          Boston  MA 02215
#
# [185950 rows x 9 columns]

# %%
data_completa['Hour Order']=data_completa['Order Date'].dt.hour

# %%
data_completa.groupby('Hour Order').sum().sort_values('Quantity Ordered',ascending==False)
# Out:
#             Quantity Ordered  Price Each  Month Order       Sales
# Hour Order
# 19                     14470  2398588.31        91389  2412938.54
# 12                     14202  2299876.68        89161  2316821.34
# 11                     14005  2288855.18        87654  2300610.24
# 18                     13802  2207696.93        86421  2219348.30
# 20                     13768  2268185.16        86375  2281716.24
# 13                     13685  2139743.86        85808  2155389.80
# 14                     12362  2072194.77        77836  2083672.73
# 10                     12308  1932665.62        76928  1944286.77
# 21                     12244  2030763.83        77103  2042000.86
# 17                     12229  2116777.02        77454  2129361.61
# 16                     11662  1892454.54        72939  1904601.31
# 15                     11391  1931174.99        72060  1941549.60
# 22                      9899  1599464.44        62088  1607549.21
# 9                       9816  1628498.49        60981  1639030.58
# 23                      7065  1172625.87        44364  1179304.44
# 8                       7002  1185970.62        43626  1192348.97
# 7                       4556   740568.11        28850   744854.12
# 0                       4428   709296.70        27554   713721.27
# 6                       2810   445000.11        17539   448113.00
# 1                       2619   458490.00        16657   460866.88
# 5                       1493   229621.21         9301   230679.82
# 2                       1398   233833.64         8507   234851.44
# 4                        937   162058.18         6148   162661.01
# 3                        928   144726.42         5904   145757.89

# %%
cantidadVendida_horas= data_completa.groupby('Hour Order').sum()['Quantity Ordered']
horas= [hora for hora, df in data_completa.groupby('Hour Order')]
plt.plot(horas,cantidadVendida_horas)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### la hora en donde se venden más  por la noche es a las 7 pm y  por la mañana- tarde es de las 10 am a las 12 pm, donde hay mayor probabilidad que si se lanza un anuncio, ocurra la venta

# %% [markdown]
# ### ¿Qué productos se venden juntos con más frecuencia?

# %%
#duplicated(keep = first obtiene el primero, last obtiene el ultimo , False obtiene todos los registros)
df=data_completa[data_completa['Order ID'].duplicated(keep= False)]

# %%
#df.groupby('Order ID')['Product'] se agrupa por orden y por agrupacion se tiene el nombre de los productos
df['Grouped']= df.groupby('Order ID')['Product'].transform(lambda  x: ",".join(x))
# Out:
# <ipython-input-116-1aee526816c4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped']= df.groupby('Order ID')['Product'].transform(lambda  x: ",".join(x))

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 20       248171        USB-C Charging Cable                 1       11.95
# 21       248171        USB-C Charging Cable                 1       11.95
# 60       248210                      iPhone                 1      700.00
# 61       248210    Lightning Charging Cable                 1       14.95
# 70       248219  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186803   194050        USB-C Charging Cable                 1       11.95
# 186809   194056                      iPhone                 1      700.00
# 186810   194056    Lightning Charging Cable                 1       14.95
# 186815   194061                      iPhone                 1      700.00
# 186816   194061    Lightning Charging Cable                 3       14.95
#
#                 Order Date                            Purchase Address  \
# 20     2019-09-05 15:06:00        705 Hill St, New York City, NY 10001
# 21     2019-09-05 15:06:00        705 Hill St, New York City, NY 10001
# 60     2019-09-27 10:33:00  292 Washington St, San Francisco, CA 94016
# 61     2019-09-27 10:33:00  292 Washington St, San Francisco, CA 94016
# 70     2019-09-24 12:48:00         665 Maple St, Los Angeles, CA 90001
# ...                    ...                                         ...
# 186803 2019-04-27 00:27:00         997 9th St, San Francisco, CA 94016
# 186809 2019-04-10 10:05:00         280 7th St, San Francisco, CA 94016
# 186810 2019-04-10 10:05:00         280 7th St, San Francisco, CA 94016
# 186815 2019-04-14 20:22:00               209 6th St, Atlanta, GA 30301
# 186816 2019-04-14 20:22:00               209 6th St, Atlanta, GA 30301
#
#         Month Order   Sales                      City  Hour Order  \
# 20                9   11.95   New York City  NY 10001          15
# 21                9   11.95   New York City  NY 10001          15
# 60                9  700.00   San Francisco  CA 94016          10
# 61                9   14.95   San Francisco  CA 94016          10
# 70                9   99.99     Los Angeles  CA 90001          12
# ...             ...     ...                       ...         ...
# 186803            4   11.95   San Francisco  CA 94016           0
# 186809            4  700.00   San Francisco  CA 94016          10
# 186810            4   14.95   San Francisco  CA 94016          10
# 186815            4  700.00         Atlanta  GA 30301          20
# 186816            4   44.85         Atlanta  GA 30301          20
#
#                                            Grouped
# 20       USB-C Charging Cable,USB-C Charging Cable
# 21       USB-C Charging Cable,USB-C Charging Cable
# 60                 iPhone,Lightning Charging Cable
# 61                 iPhone,Lightning Charging Cable
# 70         Bose SoundSport Headphones,Google Phone
# ...                                            ...
# 186803  AA Batteries (4-pack),USB-C Charging Cable
# 186809             iPhone,Lightning Charging Cable
# 186810             iPhone,Lightning Charging Cable
# 186815             iPhone,Lightning Charging Cable
# 186816             iPhone,Lightning Charging Cable
#
# [14649 rows x 11 columns]

# %%
#eliminar las filas duplicadas ya que por cada fila se hizo la union de los productos
df.drop_duplicates(inplace=True)
# Out:
# <ipython-input-118-0a4d9ddd513a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 20       248171        USB-C Charging Cable                 1       11.95
# 60       248210                      iPhone                 1      700.00
# 61       248210    Lightning Charging Cable                 1       14.95
# 70       248219  Bose SoundSport Headphones                 1       99.99
# 71       248219                Google Phone                 1      600.00
# ...         ...                         ...               ...         ...
# 186803   194050        USB-C Charging Cable                 1       11.95
# 186809   194056                      iPhone                 1      700.00
# 186810   194056    Lightning Charging Cable                 1       14.95
# 186815   194061                      iPhone                 1      700.00
# 186816   194061    Lightning Charging Cable                 3       14.95
#
#                 Order Date                            Purchase Address  \
# 20     2019-09-05 15:06:00        705 Hill St, New York City, NY 10001
# 60     2019-09-27 10:33:00  292 Washington St, San Francisco, CA 94016
# 61     2019-09-27 10:33:00  292 Washington St, San Francisco, CA 94016
# 70     2019-09-24 12:48:00         665 Maple St, Los Angeles, CA 90001
# 71     2019-09-24 12:48:00         665 Maple St, Los Angeles, CA 90001
# ...                    ...                                         ...
# 186803 2019-04-27 00:27:00         997 9th St, San Francisco, CA 94016
# 186809 2019-04-10 10:05:00         280 7th St, San Francisco, CA 94016
# 186810 2019-04-10 10:05:00         280 7th St, San Francisco, CA 94016
# 186815 2019-04-14 20:22:00               209 6th St, Atlanta, GA 30301
# 186816 2019-04-14 20:22:00               209 6th St, Atlanta, GA 30301
#
#         Month Order   Sales                      City  Hour Order  \
# 20                9   11.95   New York City  NY 10001          15
# 60                9  700.00   San Francisco  CA 94016          10
# 61                9   14.95   San Francisco  CA 94016          10
# 70                9   99.99     Los Angeles  CA 90001          12
# 71                9  600.00     Los Angeles  CA 90001          12
# ...             ...     ...                       ...         ...
# 186803            4   11.95   San Francisco  CA 94016           0
# 186809            4  700.00   San Francisco  CA 94016          10
# 186810            4   14.95   San Francisco  CA 94016          10
# 186815            4  700.00         Atlanta  GA 30301          20
# 186816            4   44.85         Atlanta  GA 30301          20
#
#                                            Grouped
# 20       USB-C Charging Cable,USB-C Charging Cable
# 60                 iPhone,Lightning Charging Cable
# 61                 iPhone,Lightning Charging Cable
# 70         Bose SoundSport Headphones,Google Phone
# 71         Bose SoundSport Headphones,Google Phone
# ...                                            ...
# 186803  AA Batteries (4-pack),USB-C Charging Cable
# 186809             iPhone,Lightning Charging Cable
# 186810             iPhone,Lightning Charging Cable
# 186815             iPhone,Lightning Charging Cable
# 186816             iPhone,Lightning Charging Cable
#
# [14385 rows x 11 columns]

# %%
from itertools import combinations
from collections import Counter
count = Counter()
for row in df['Grouped']:
    row_list= row.split(',')
    count.update(Counter(combinations(row_list,2)))
    
for key, value in count.most_common(12):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 2133
# ('Google Phone', 'USB-C Charging Cable') 2111
# ('iPhone', 'Wired Headphones') 987
# ('Google Phone', 'Wired Headphones') 946
# ('iPhone', 'Apple Airpods Headphones') 799
# ('Vareebadd Phone', 'USB-C Charging Cable') 773
# ('Google Phone', 'Bose SoundSport Headphones') 503
# ('USB-C Charging Cable', 'Wired Headphones') 449
# ('Vareebadd Phone', 'Wired Headphones') 327
# ('Lightning Charging Cable', 'Wired Headphones') 253
# ('Lightning Charging Cable', 'Apple Airpods Headphones') 214
# ('USB-C Charging Cable', 'Bose SoundSport Headphones') 211

# %% [markdown]
# #### los productos que con mayor frecuencia se venden juntos

# %% [markdown]
# ## ¿Qué producto se vendió más? ¿Por qué crees que vendió más?

# %%
data_completa.groupby('Product').sum().sort_values('Quantity Ordered', ascending= False)['Quantity Ordered']
# Out:
# Product
# AAA Batteries (4-pack)        31017
# AA Batteries (4-pack)         27635
# USB-C Charging Cable          23975
# Lightning Charging Cable      23217
# Wired Headphones              20557
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# 27in FHD Monitor               7550
# iPhone                         6849
# 27in 4K Gaming Monitor         6244
# 34in Ultrawide Monitor         6199
# Google Phone                   5532
# Flatscreen TV                  4819
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# 20in Monitor                   4129
# Vareebadd Phone                2068
# LG Washing Machine              666
# LG Dryer                        646
# Name: Quantity Ordered, dtype: int32

# %%
#verlo en grafico
productos= [product for product,df in data_completa.groupby('Product')]
ventas_productos= data_completa.groupby('Product').sum()['Quantity Ordered']
plt.bar(productos,ventas_productos)
plt.xticks(productos, rotation='vertical', size=15)
plt.xlabel("productos")
plt.ylabel("ventas")
plt.show()

# %% [markdown]
# #### El producto que mayor se vendio fue AAA Batteries (4-pack), ya que es un producto de menor costo

# %%
#comparar con los precios de los productos
precios= data_completa.groupby('Product').mean()['Price Each']

# %%
#poner dos graficos en uno solo
fit,ax1= plt.subplots()
ax2= ax1.twinx()

ax1.bar(productos,ventas_productos)
ax2.plot(productos,precios, color='red')

ax1.set_xlabel("productos")
ax1.set_ylabel("ventas")
ax2.set_ylabel("precios")
ax1.set_xticklabels(productos, rotation='vertical', size=15)
plt.show()
# Out:
# <ipython-input-149-203d4aff2aa8>:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(productos, rotation='vertical', size=15)
